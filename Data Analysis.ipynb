# %% [markdown]
# # Set up

# %%
# %reload_ext autoreload
# %autoreload 2

# %cd /Users/dunglai/Documents/Việt Dũng/Personal Projects/World Foresight Framework/Data Preparation
# Out:
# /Users/dunglai/Documents/Việt Dũng/Personal Projects/World Foresight Framework/Data Preparation

# %%
from pathlib import Path
import pandas as pd

pd.set_option("display.max_columns", 120)
pd.set_option("display.width", 220)

PROJECT_ROOT = Path("/Users/dunglai/Documents/Việt Dũng/Personal Projects/World Foresight Framework")

# %%
full_data_to_2040 = pd.read_excel(
    PROJECT_ROOT / "Final Data.xlsx",
    sheet_name="Final Full Data",
)

full_data_to_2040["value"] = full_data_to_2040["value"].astype(float)
full_data_to_2040["year"] = full_data_to_2040["year"].astype(int)


full_data_to_2040.head(5)
# Out:
#   proxy_id  id market  year        value          labels    scenario  lower_ci  upper_ci
# 0   D1_ARE  D1    ARE  2000  5875.833901  USD (millions)  historical       NaN       NaN
# 1   D1_ARE  D1    ARE  2001  5797.957794  USD (millions)  historical       NaN       NaN
# 2   D1_ARE  D1    ARE  2002  5354.118448  USD (millions)  historical       NaN       NaN
# 3   D1_ARE  D1    ARE  2003  5834.717495  USD (millions)  historical       NaN       NaN
# 4   D1_ARE  D1    ARE  2004  6816.882233  USD (millions)  historical       NaN       NaN

# %%
main_2040_data = full_data_to_2040[ 
    (full_data_to_2040["year"]==2040) & 
    (full_data_to_2040["scenario"]=="main_scenario")
]

main_2030_data = full_data_to_2040[ 
    (full_data_to_2040["year"]==2030) & 
    (full_data_to_2040["scenario"]=="main_scenario") 
]

main_2025_data = full_data_to_2040[
    (full_data_to_2040["year"] == 2025) &
    (full_data_to_2040["scenario"].isin(["historical", "main_scenario"]))
]

print("2025 Data:")
display(main_2025_data.head(3))
print("2030 Data:")
display(main_2030_data.head(3))
print("2040 Data:")
display(main_2040_data.head(3))
# Out:
# 2025 Data:
#     proxy_id  id market  year         value          labels       scenario      lower_ci      upper_ci
# 45    D1_ARE  D1    ARE  2025  35369.411287  USD (millions)  main_scenario  15585.850817  80263.192511
# 118   D1_ARG  D1    ARG  2025   3875.750072  USD (millions)     historical           NaN           NaN
# 189   D1_AUS  D1    AUS  2025  35326.559811  USD (millions)     historical           NaN           NaN
# 2030 Data:
#     proxy_id  id market  year         value          labels       scenario      lower_ci      upper_ci
# 60    D1_ARE  D1    ARE  2030  36368.854963  USD (millions)  main_scenario  13536.299962  97711.716257
# 131   D1_ARG  D1    ARG  2030   4383.320625  USD (millions)  main_scenario   1229.442499  15621.239438
# 202   D1_AUS  D1    AUS  2030  43018.445605  USD (millions)  main_scenario  24936.815868  74210.499112
# 2040 Data:
#     proxy_id  id market  year         value          labels       scenario      lower_ci       upper_ci
# ...

# %%
statistical_data = pd.read_excel(
    PROJECT_ROOT / "Final Data.xlsx",
    sheet_name="Statistical Data",
)
statistical_data.head(5)
# Out:
#    id proxy_id market  n_obs  first_year  latest_year  latest_value   latest_y  slope_p1y  slope_p3y  slope_full  cagr_p1y  cagr_p3y  cagr_full  trend_r2_raw  trend_r2_y  residual_std  y_change_volatility  \
# 0  D1   D1_ARE    ARE     15        2000         2014  22755.071477  10.032587  -0.095260   0.180321    0.167747 -0.034209  0.058595   0.101541      0.889511    0.927646      0.150654             0.118678
# 1  D1   D1_ARG    ARG     26        2000         2025   3875.750072   8.262752  -0.090207  -0.062001    0.030397 -0.072751 -0.036881   0.006863      0.367010    0.399486      0.346498             0.271699
# 2  D1   D1_AUS    AUS     26        2000         2025  35326.559811  10.472419   0.043277   0.041444    0.043571  0.031991  0.028765   0.065255      0.931372    0.851506      0.190508             0.086353
# ...

# %% [markdown]
# # Topic 1: Power

# %% [markdown]
# ## Q1: What shape does the world order take?
#
# Proxies used to answer this: D1, D2, D3, D4, D5

# %%
# Ranking of countries by time
from Analysis_Functions.market_relevance import rank_market_relevance

proxy_direction_config = [
    {"id": "D1", "direction": "positive"},
    {"id": "D2", "direction": "positive"},
    {"id": "D3", "direction": "positive"},
    {"id": "D4", "direction": "positive"},
    {"id": "D5", "direction": "positive"},
]

main_2025_data_q1 = main_2025_data[main_2025_data["id"].isin(["D1", "D2", "D3", "D4", "D5"])]
main_2030_data_q1 = main_2030_data[main_2030_data["id"].isin(["D1", "D2", "D3", "D4", "D5"])]
main_2040_data_q1 = main_2040_data[main_2040_data["id"].isin(["D1", "D2", "D3", "D4", "D5"])]

# %%
# Rank year 2025
market_relevance_ranking = rank_market_relevance(
    main_2025_data_q1,
    proxy_direction_config,
)

display(market_relevance_ranking.sort_values(["rank"]).head(10))
# Out:
#   market  final_score  rank
# 0    CHN   100.000000     1
# 1    USA   100.000000     1
# 2    DEU    78.265136     3
# 3    IND    70.473435     4
# 4    GBR    70.221145     5
# 5    JPN    68.989771     6
# 6    FRA    65.065003     7
# 7    RUS    62.211959     8
# 8    CAN    56.777350     9
# 9    KOR    56.423913    10

# %%
# Rank year 2030
market_relevance_ranking = rank_market_relevance(
    main_2030_data_q1,
    proxy_direction_config,
)

display(market_relevance_ranking.sort_values(["rank"]).head(10))
# Out:
#   market  final_score  rank
# 0    CHN   100.000000     1
# 1    USA   100.000000     1
# 2    DEU    75.780908     3
# 3    IND    71.527456     4
# 4    GBR    67.433051     5
# 5    JPN    66.986944     6
# 6    FRA    63.336969     7
# 7    RUS    62.928614     8
# 8    KOR    56.693156     9
# 9    CAN    56.171870    10

# %%
# Rank year 2040
market_relevance_ranking = rank_market_relevance(
    main_2040_data_q1,
    proxy_direction_config,
)

display(market_relevance_ranking.sort_values(["rank"]).head(10))
# Out:
#   market  final_score  rank
# 0    CHN   100.000000     1
# 1    USA   100.000000     1
# 2    DEU    74.699252     3
# 3    IND    72.115900     4
# 4    JPN    66.313580     5
# 5    GBR    65.530177     6
# 6    RUS    63.654181     7
# 7    FRA    62.332020     8
# 8    KOR    57.428775     9
# 9    CAN    56.283426    10

# %%
market_relevance_ranking = rank_market_relevance(
    main_2040_data_q1,
    proxy_direction_config,
)

display(market_relevance_ranking.sort_values(["rank"]).head(10))
# Out:
#   market  final_score  rank
# 0    CHN   100.000000     1
# 1    USA   100.000000     1
# 2    DEU    74.699252     3
# 3    IND    72.115900     4
# 4    JPN    66.313580     5
# 5    GBR    65.530177     6
# 6    RUS    63.654181     7
# 7    FRA    62.332020     8
# 8    KOR    57.428775     9
# 9    CAN    56.283426    10

# %%
# ...
from Analysis_Functions.share_of_world import analyze_share_of_world

proxy_ids = ["D1", "D2", "D4", "D5"]

# %%
# Rank year 2025
ranking_df, hhi_df, share_detail_df = analyze_share_of_world(
    main_2025_data_q1,
    proxy_ids,
)

print("Ranking by average world share")
display(ranking_df.head(5))

print("HHI:")
display(hhi_df)

print("Top world share by proxy")
display(share_detail_df.head(4))
# Out:
# Ranking by average world share
#   market  average_share  rank
# 0    USA      24.973039     1
# 1    CHN      20.166007     2
# 2    IND       6.081974     3
# 3    DEU       4.900699     4
# 4    RUS       4.104511     5
# HHI:
#    id          hhi  effective_markets
# 0  D1  1757.592021           5.689603
# 1  D2   826.396424          12.100730
# 2  D4  1513.050812           6.609163
# 3  D5  1329.055556           7.524140
# Top world share by proxy
#    id market      share  rank
# 0  D1    USA  37.680055     1
# 1  D2    CHN  17.018355     1
# 2  D4    USA  30.729396     1
# 3  D5    CHN  29.491154     1

# %%
# Rank year 2030
ranking_df, hhi_df, share_detail_df = analyze_share_of_world(
    main_2030_data_q1,
    proxy_ids,
)

print("Ranking by average world share")
display(ranking_df.head(5))

print("HHI:")
display(hhi_df)

print("Top world share by proxy")
display(share_detail_df.head(4))
# Out:
# Ranking by average world share
#   market  average_share  rank
# 0    USA      23.503468     1
# 1    CHN      22.014902     2
# 2    IND       6.400205     3
# 3    DEU       4.656615     4
# 4    RUS       4.319114     5
# HHI:
#    id          hhi  effective_markets
# 0  D1  1636.211228           6.111680
# 1  D2   838.691471          11.923336
# 2  D4  1513.551512           6.606977
# 3  D5  1360.042809           7.352710
# Top world share by proxy
#    id market      share  rank
# 0  D1    USA  34.731314     1
# 1  D2    CHN  18.321918     1
# 2  D4    USA  28.853578     1
# 3  D5    CHN  30.130440     1

# %%
# Rank year 2040
ranking_df, hhi_df, share_detail_df = analyze_share_of_world(
    main_2040_data_q1,
    proxy_ids,
)

print("Ranking by average world share")
display(ranking_df.head(5))

print("HHI:")
display(hhi_df)

print("Top world share by proxy")
display(share_detail_df.head(4))
# Out:
# Ranking by average world share
#   market  average_share  rank
# 0    CHN      23.082729     1
# 1    USA      22.510386     2
# 2    IND       6.631141     3
# 3    DEU       4.529101     4
# 4    RUS       4.487829     5
# HHI:
#    id          hhi  effective_markets
# 0  D1  1565.613386           6.387273
# 1  D2   833.690687          11.994856
# 2  D4  1521.770452           6.571293
# 3  D5  1379.487352           7.249070
# Top world share by proxy
#    id market      share  rank
# 0  D1    USA  32.451407     1
# 1  D2    CHN  18.470046     1
# 2  D4    USA  27.684029     1
# 3  D5    CHN  30.524861     1

# %%
# Biggest movers in world power-share (2025 -> 2040)
share_proxy_ids = ["D1", "D2", "D4", "D5"]

rank_2025, _, _ = analyze_share_of_world(main_2025_data_q1, share_proxy_ids)
rank_2040, _, _ = analyze_share_of_world(main_2040_data_q1, share_proxy_ids)

movers = (
    rank_2025[["market", "average_share"]].rename(columns={"average_share": "share_2025"})
    .merge(
        rank_2040[["market", "average_share"]].rename(columns={"average_share": "share_2040"}),
        on="market",
    )
)
movers["change"] = movers["share_2040"] - movers["share_2025"]
movers = movers.sort_values("change", ascending=False).reset_index(drop=True)

print("Biggest risers (world power-share, pct points):")
display(movers.head(6).round(2))
print("Biggest fallers:")
display(movers.tail(6).round(2))
# Out:
# Biggest risers (world power-share, pct points):
#   market  share_2025  share_2040  change
# 0    CHN       20.17       23.08    2.92
# 1    IND        6.08        6.63    0.55
# 2    RUS        4.10        4.49    0.38
# 3    VNM        1.09        1.27    0.18
# 4    IDN        1.53        1.66    0.12
# 5    POL        1.40        1.51    0.11
# Biggest fallers:
#    market  share_2025  share_2040  change
# 28    ITA        2.22        1.95   -0.26
# 29    FRA        3.04        2.74   -0.30
# 30    DEU        4.90        4.53   -0.37
# 31    GBR        3.52        3.14   -0.38
# 32    JPN        3.47        2.99   -0.48
# 33    USA       24.97       22.51   -2.46

# %%
# Bloc-level combined world power-share (2025 vs 2040)
blocs = {
    "West (US + NATO/EU + Pacific)": ["USA", "CAN", "GBR", "FRA", "DEU", "ITA", "NLD", "POL", "JPN", "KOR", "AUS"],
    "China + Russia":                ["CHN", "RUS"],
    "India (swing pole)":            ["IND"],
}
assigned = {m for members in blocs.values() for m in members}
blocs["Rest / Global South"] = [m for m in movers["market"] if m not in assigned]

bloc_rows = []
for name, members in blocs.items():
    s25 = movers.loc[movers["market"].isin(members), "share_2025"].sum()
    s40 = movers.loc[movers["market"].isin(members), "share_2040"].sum()
    bloc_rows.append({"bloc": name, "share_2025": s25, "share_2040": s40, "change": s40 - s25})

bloc_shares = pd.DataFrame(bloc_rows).round(1)
display(bloc_shares)
# Out:
#                             bloc  share_2025  share_2040  change
# 0  West (US + NATO/EU + Pacific)        51.3        47.0    -4.4
# 1                 China + Russia        24.3        27.6     3.3
# 2             India (swing pole)         6.1         6.6     0.5
# 3            Rest / Global South        18.5        19.0     0.5

# %%
# Effective number of great powers
def effective_poles(data_q1):
    rank_df, _, _ = analyze_share_of_world(data_q1, share_proxy_ids)
    p = rank_df["average_share"] / 100.0
    return 1.0 / (p ** 2).sum()

for label, data_q1 in [("2025", main_2025_data_q1), ("2030", main_2030_data_q1), ("2040", main_2040_data_q1)]:
    print(f"{label}: {effective_poles(data_q1):.1f} effective great powers")
# Out:
# 2025: 8.4 effective great powers
# 2030: 8.4 effective great powers
# 2040: 8.4 effective great powers
